# %%
# %run fix_nat_error.py
# Out:
# 🔧 Cargando funciones corregidas...
# ✅ Funciones cargadas exitosamente:
#    - normalize_datetimes()
#    - sanitize_for_mongo()
#    - insert_data_to_mongodb()
#
# 🚀 Ahora ejecuta la celda de carga de archivos (celda 24)
